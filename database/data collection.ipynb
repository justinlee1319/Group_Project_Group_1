# %% [markdown]
# ### Data collection

# %%
import pandas as pd
import sqlite3
import csv

# %%
csv_path = r'E:\Data Analytics\DAB111 python\group project\my zip\my zip\twitchdata-update.csv'
df = pd.read_csv(csv_path)

# %%
df.head()
# Out:
#     Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 0     xQcOW           6196161750                215250        222720
# 1  summit1g           6091677300                211845        310998
# 2    Gaules           5644590915                515280        387315
# 3  ESL_CSGO           3970318140                517740        300575
# 4      Tfue           3671000070                123660        285644
#
#    Average viewers  Followers  Followers gained  Views gained  Partnered  \
# 0            27716    3246298           1734810      93036735       True
# 1            25610    5310163           1370184      89705964       True
# 2            10976    1767635           1023779     102611607       True
# 3             7714    3944850            703986     106546942       True
# 4            29602    8938903           2068424      78998587       True
#
#    Mature    Language
# 0   False     English
# 1   False     English
# 2    True  Portuguese
# ...

# %%
con = sqlite3.connect('Twitch_data.db')
cursor = con.cursor()

# %%
df.to_sql('twitch_data', con, index=False, if_exists='replace')
# Out:
# 1000

# %%
rows = cursor.execute("SELECT * FROM twitch_data").fetchall()
rows
# Out:
# [('xQcOW',
#   6196161750,
#   215250,
#   222720,
#   27716,
#   3246298,
#   1734810,
#   93036735,
#   1,
#   0,
#   'English'),
#  ('summit1g',
#   6091677300,
#   211845,
#   310998,
#   25610,
#   5310163,
#   1370184,
#   89705964,
#   1,
#   0,
#   'English'),
#  ('Gaules',
#   5644590915,
#   515280,
#   387315,
#   10976,
#   1767635,
#   1023779,
#   102611607,
#   1,
#   1,
#   'Portuguese'),
#  ('ESL_CSGO',
#   3970318140,
#   517740,
#   300575,
#   7714,
#   3944850,
#   703986,
#   106546942,
#   1,
#   0,
#   'English'),
#  ('Tfue',
#   3671000070,
#   123660,
#   285644,
#   29602,
#   8938903,
#   2068424,
#   78998587,
#   1,
#   0,
#   'English'),
#  ('Asmongold',
#   3668799075,
#   82260,
#   263720,
#   42414,
#   1563438,
#   554201,
#   61715781,
#   1,
#   0,
#   'English'),
#  ('NICKMERCS',
#   3360675195,
#   136275,
#   115633,
#   24181,
#   4074287,
#   1089824,
#   46084211,
#   1,
#   0,
#   'English'),
#  ('Fextralife',
#   3301867485,
#   147885,
# ...

# %%
# create_table = """CREATE TABLE IF NOT EXISTS twitch_data(
#                             Channel TEXT PRIMARY KEY,
#                             "Watch time(Minutes)" INTEGER,
#                             "Stream time(minutes)" INTEGER,
#                             "Peak viewers" INTEGER,
#                             "Average viewers" INTEGER,
#                             Followers INTEGER,
#                             "Followers gained" INTEGER,
#                             "Views gained" INTEGER,
#                             Partnered TEXT,
#                             Mature  TEXT,
#                             Language TEXT)"""
# cursor.execute(create_table)

# %%
# with open('twitchdata-update.csv', encoding='utf-8') as f:
#     data = csv.reader(f)
#     header = next(data, None)
#     for row in data:
#         cursor.execute("INSERT INTO twitch_data VALUES(?,?,?,?,?,?,?,?,?,?,?)", row)
